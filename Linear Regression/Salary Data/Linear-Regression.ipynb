# %%
import numpy as np
import pandas as pd #Data Analysis
import matplotlib.pyplot as plt #Data Visualisation
import seaborn as sns #Data Visualisation

# %%
data = pd.read_csv("salarydata.csv")
print(data.head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv("salarydata.csv")
#       2 print(data.head(5))
#
# NameError: name 'pd' is not defined

# %% [markdown]
# <h1>Data Visualisation </h1>

# %%
sns.scatterplot(x="YearsExperience", y="Salary", data=data, color="blue")
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
plt.scatter(data.YearsExperience,data.Salary, color="red")

# %%
print(data.corr()) # r = co-efficient as co-relation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(data.corr()) # r = co-efficient as co-relation
#
# NameError: name 'data' is not defined

# %%
from sklearn.linear_model import LinearRegression
